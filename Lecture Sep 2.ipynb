# %%
#Derivatives

#Numerical Derivatives
#opposite of a numerical integral
#Little to discuss because
#1 basic techniques are quite sumple
#2 derivatives of known functions calculated analytically
#3 significant practical problems with numerical derivatives

#forward and backward differences
